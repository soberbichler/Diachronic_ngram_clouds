# %% [markdown]
# # Discover a newspaper collection with diachronic Ngram clouds

# %% [markdown]
# Ngrams are connected sequences of n items from a given text or speech sample. This means that words are not considered as individual units, but in relation to each other. For scholars in the humanities, ngrams can be helpful to get an overview of their collection or to identify discourse markers (discourse = a group of related texts belonging to a common system of formation). Ngrams can never be a research result per se - which is true for any output of NLP methods - but they can help to find important patterns in a particular collection.
#
# ![Collection on the topic of Emigration](images/WC.PNG)
#
# If ngrams are used to identify discourse markers, it can be useful to crate diachrinic Ngrams to explore the change of rextual patterns. This Notebook therefore shows how diachronic ngrams can be build and visualized. For cultural heritage material, visualizations should make it possible to open up and experience the collections in new ways. But they should always be linked to the original documents.
#
# The graphic representation and the original material cannot be perceived as two different elements, they are rather  interwoven and interact with each other. Therefore, this Notebook allows to browse the original texts within the Notebook. Thus the results of the ngram clouds can be researched in the context of the original text.
#
# Acknowledgments:
#
# This work was supported by the European Union's Horizon 2020 research and innovation programme under grant 770299 (NewsEye).

# %% [markdown]
# ## Step by step...
# * [Prepare your collection](#1-bullet)
# * [Install packages in command line](#2-bullet)
# * [Import packages](#3-bullet)
# * [Import your collection](#4-bullet)
# * [Clean and tokenize the text (pre-processing)](#5-bullet)
# * [Build the bigram and trigram models](#6-bullet)
# * [Have a look at your collection - Create an onegram, bigram or trigram](#7-bullet)
# * [Discover diachronic n-grams for specific years or time periods](#8-bullet)
# * [Browse original texts](#9-bullet)

# %% [markdown]
# ## Prepare your collection <a class="anchor" id="1-bullet"></a>
#
# Your collection should at least contain the original text and information on the data of origin.

# %% [markdown]
# ## Install packages in command line <a class="anchor" id="2-bullet"></a>
#
# If you need help on how to pip install, have a look at this tutorial: https://packaging.python.org/tutorials/installing-packages/
#
# pip install gensim
#
# pip install PyLDAvis
#
# pip install spacy
#
# python -m spacy download de_core_web_sm
#
# pip install pandas
#
# pip install regex
#
# pip install nltk
#
# pip install matplotlib
#
# pip install numpy

# %% [markdown]
# ## Import packages <a class="anchor" id="3-bullet"></a>
#
# Before you can get started, you have to install and import some packages.

# %%
#languange processing imports
import gensim, spacy, logging, warnings
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
import sys
import re, numpy as np, pandas as pd
from pprint import pprint
from nltk.stem.porter import PorterStemmer
from gensim.utils import lemmatize, simple_preprocess

#For the text overview
from nltk import FreqDist

#Word Cloud and Visualization

from wordcloud import WordCloud, STOPWORDS
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Import your newspaper collection <a class="anchor" id="2-bullet"></a>
# And have a look at your data

# %%
df = pd.read_csv('y_sudtirol.csv', encoding='latin-1')

# %%
df.head(10)
# Out:
#      year                                               text
# 0  1945.0  den. Es wird al" unwahrscheinlich bezeichnet d...
# 1  1945.0  waffnung österreichs die Brennergrenze ihre mi...
# 2  1945.0  Wien Samstag den 8. September 1948 kür die Rüc...
# 3  1945.0  beschlossen: Das Schicksal Südtirols beschäfti...
# 4  1945.0  Bis zum Jahre 1918 gab es in diesem Gebiete  ...
# 5  1945.0  tragung ausschließlich st rategische Gesichtsp...
# 6  1945.0  «sch anzusehenden Memoircnwerk Von Rah Stannar...
# 7  1945.0  Diese fei schreibt der "Daily T e l e g r a p ...
# 8  1945.0    Wiedervereinigung mit den übrige« tirolifchest
# 9  1945.0  Zum Schluß komme ich au st das außenpolitische...

# %% [markdown]
# ## Clean and tokenize the text (pre-processing) <a class="anchor" id="5-bullet"></a>
#
# Before you can start to train the bigram and trigram models, you have to clean the text of your newspaper text blocks. The follwing functions remove punctuations, lower case the text, remove stop words and stem the text.
#
# #### Stop words:
# You can change the language used for the stop words. You can also add your own stop words or other words you would like to ignore. It helps to ignore your search keywords.

# %%
# Functions to clean, tokenize, and stem the data
def initial_clean(text):
    text = re.sub(r'[^\w\s]','',text)
    text = text.lower() 
    text = nltk.word_tokenize(text)
    return text

stop_words = stopwords.words('german')#change the language here
# add your onw stop words
stop_words.extend(['italienisch', 'Italien', 'italienische', 'österreich', 'österreichischen', 'österreichisch','südtirolerplatz', 'südtirol', 'südtiroler', 'südtirolern', 'südtirols'])
def remove_stop_words(text):
    return [word for word in text if word not in stop_words]

stemmer = PorterStemmer()
def stem_words(text):
    try:
        text = [stemmer.stem(word) for word in text]
        text = [word for word in text if len(word) > 1] 
    except IndexError: 
        pass
    return text

def apply_all(text):
    return stem_words(remove_stop_words(initial_clean(text)))

# %%
df['tokenized'] = df['text'].apply(apply_all) 
print(df['tokenized'])
# Out:
# 0       [al, unwahrscheinlich, bezeichnet, genf, ständ...
# 1       [waffnung, österreich, brennergrenz, militäris...
# 2       [wien, samstag, septemb, 1948, kür, rückkehr, ...
# 3       [beschlossen, schicksal, beschäftigt, neürd, w...
# 4       [jahr, 1918, gab, gebiet, abgesehen, gegend, e...
#                               ...
# 3222    [wahlen, südfiroi, rom, dezemb, wk, ergebniss,...
# 3223    [rücksiediupg, südtroler, unterstützen, wien, ...
# 3224    [bundesministerium, inner, gebildet, aufgab, k...
# 3225    [politischen, wirtschaftlichen, verhältniss, w...
# 3226    [außenminist, graf, sforza, österreichisch, au...
# Name: tokenized, Length: 3227, dtype: object

# %% [markdown]
# ## Build the bigram and trigram models <a class="anchor" id="6-bullet"></a>
# To see how often word X is followed by word Y, we build a model of the relationships between them.
#
# We also reduce the data to nouns, adjectives, verses and opponents. The package Spacy is used for the pos tagging. Spacy can be used in many differnt languages. To use Spazy in your preferred language, you have to install the right model. This model can be found here: https://spacy.io/usage/models.
#
# We lemmatize the text and remove stop words once more after lemmatization.

# %%
bigram = gensim.models.Phrases(df['tokenized'], min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[df['tokenized']], threshold=100)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)
spacy.prefer_gpu()

def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    texts_out = []
    nlp = spacy.load('de_core_news_sm', disable=['parser', 'ner'])
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out
    # remove stopwords once more after lemmatization


data_ready = process_words(df['tokenized'])  # processed Text Data!

# %% [markdown]
# ## Have a look at your collection - Create an onegram, bigram or trigram <a class="anchor" id="7-bullet"></a>
#
# Have a look at your whole collection. In the line: vectorizer = CountVectorizer(ngram_range=(3, 3)) you can change the range of the Ngram. For onegrams use (1, 1), for bigrams (2, 2) and for trigrams (3, 3).

# %%
bigrams_list = list(nltk.bigrams(data_ready))
#print(bigrams_list)

dictionary = [' '.join([str(tup) for tup in bigrams_list])]
#print(dictionary2)

#Using count vectoriser to view the frequency of bigrams
data_ready = process_words(df['tokenized'])  # processed Text Data!
bigrams_list = list(nltk.bigrams(data_ready))
dictionary = [' '.join([str(tup) for tup in bigrams_list])]
vectorizer = CountVectorizer(ngram_range=(3, 3))
bag_of_words = vectorizer.fit_transform(dictionary)
vectorizer.vocabulary_
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
words_dict = dict(words_freq)
WC_height = 1500
WC_width = 2000
WC_max_words = 200
wordCloud = WordCloud(max_words=WC_max_words, height=WC_height, width=WC_width)
wordCloud.generate_from_frequencies(words_dict)
plt.figure(figsize=(20, 15))
plt.plot
plt.imshow(wordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Discover diachronic n-grams for specific years or time periods <a class="anchor" id="8-bullet"></a>
#
# Here you can create diachronic Ngram clouds for specific years or time frames.

# %%
#Choose specific years or time frames you want to use for the NGram clouds
_1945 = (df['year'] > int('1944')) & (df['year'] <= int('1945'))
_1946 = (df['year'] > int('1945')) & (df['year'] <= int('1946'))
_1947_48 = (df['year'] > int('1946')) & (df['year'] <= int('1947'))

#This will be used for the title of the clouds
time_frame = ['1945', '1946', '1947-1948']

#Here you create a list containing the information on your selected time-frames
selection = []
selection.append(_1945)
selection.append(_1946)
selection.append(_1947_48)

#Get your bigrams for every selected time frame
selection[0] = df.loc[_1945]['tokenized']
selection[1] = df.loc[_1946]['tokenized']
selection[2] = df.loc[_1947_48]['tokenized']

#Create the diachronic Ngram clouds
i = -1
while i < len(selection) -1:
    i = i +1 
    data_ready2 = process_words(selection[i])  # processed Text Data!
    bigrams_list = list(nltk.bigrams(data_ready2))
    dictionary = [' '.join([str(tup) for tup in bigrams_list])]
    vectorizer = CountVectorizer(ngram_range=(2, 2))
    bag_of_words = vectorizer.fit_transform(dictionary)
    vectorizer.vocabulary_
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    words_dict = dict(words_freq)
    WC_height = 1000
    WC_width = 1500
    WC_max_words = 200
    wordCloud = WordCloud(max_words=WC_max_words, height=WC_height, width=WC_width)
    wordCloud.generate_from_frequencies(words_dict)
    plt.figure(figsize=(15, 8))
    plt.plot
    plt.imshow(wordCloud, interpolation='bilinear')
    plt.title(time_frame[i], size= 'x-large')
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## Browse original texts <a class="anchor" id="9-bullet"></a>
#
# Here you can browse through the original text. To refine the search, you can reduce the search to those texts that contain a specific word. In this example all texts were searched containg the word "amerika*".

# %%
pd.set_option('display.max_colwidth', -1)

lines_ = []
for line in df['text']:
    if 'amerika' in line:
        lines_.append(line)
    
lines_ = pd.DataFrame(lines_, columns =['Amerika'])
df_select = pd.DataFrame(lines_['Amerika'])
df_select
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Amerika
# 0   Das Kleine Volksblatt Donnerstag 4. Oktober 1945 Nr. 51 Südtirol Ein amerikanischer Journalist hat vor Jahre über die österreicher folgendes geschrieben. "Sie neigen gerne zu Parteibildungen und be kämpfen sich dann gegenseitig mit ziemlicher Hef-
# 1   M^er anderem-auch die wie das amerikanische Durch ferne eigenartige geschichtliche Entwicklung war Volk über österreichs Mitschuld am Tirol zu einer festgefügten historischen und Wirtschaft.
# 2   der Strasse ein grosser Unterschied besteht. Die der eingeengt zwischen dem Deutschen Reich und Italien amerikanischen Soldaten seien der Ansicht wer im wesevtlicheu nur aus d«m Jnuial und Hessen Seiten-  «unr Wmf- talern besteht. Das Land Tirol verlor durch die "nnatür. deutsch rrd.et. se.i eben DtzuLscher mnd damit schul- Grenzziehung am Brenner nicht nur Südtirol. ' . . WWW WY. . ... . . _es dig. Der amerskayisrhe Bürger hingegen sehe in wurde auch von Otzti.ro l g-e trennt da die
# 3   Besetzung und Erziehung Japans behandelt. Dieser Plan sieht hauptsächlich eine amerikanische Kontrolle mit Hilfe von Vertretern der vier Alliierten vor. Frankreich und die Südtiroler Frage Paris 8. September In politischen Kreisen verlautet Frankreich
# 4   der amerikanischen Armee in österreich
# 5   lienische Ministerpräsident Bonomi erklärte daß Italien dem angto-amerikanischen Sinn sür Gerechtigkeit und Billigkeit vertraün dürfe und keine harten Fricdcnsbedingungen zu befürchten habe. Bonomi drückte den Wunsch Italiens aus seine Vorkriegsgrcnzen im Norden beizubehalten. Italien halte auch an dem Brennerpaß und an der Südtiroler Alpen- grenze fest.
# 6   I n n s b r n i» 1. Juni (AND). Prof. Dr. R e « «-N ie» l u I! i Hai an Präsident Truman solgendes Telegram gerichtet: Namens des Volkes Südtirols einschliri! lich 3Ü.UUV durch Hitler und Muffolini vertrielicM Landsleute richte ich an das Volk der USA die Dci6i' Bitte die Sache der F r e i h e i 1 « n d © r r e ch tigkcit in der Tiroler Frage zu »nie! stützen. Unser gesamtes Voll beschwört die groß amerikanische Nation die Heimkehr Südtirols iij
# 7   Prinzipien zum Durchbruch verhelfe». Im Jahre 1916 wurde aber der Anspruch O e st e r- reichs durchkreuzt offenbar um T r i e st den Italienern zu erhalten wie es 1919 geschah um Fiume den Italienern vorzünthalten. Es erfüllt das österreichische Bolk mit Schmerz dah diese große und mächtige Nation ihren Einfluß nicht auch zum Schutze der Südtiroler geltend machen kann die dessen am meisten bedürfen. Die stets hilfsbereite Tatkraft amerikanischer Offiziere und Soldaten in Österreich lieh uns erwarten dah wir auch in dieser Frage auf Unterstützung hoffen dürfen. Unsere Lage 14 Monate nach der Befreiung
# 8   Italien beharrt auf seinem ablehnenden Standpunkt Rom 5. Februar (ACA) Nachdem gestern Ministerpräsident de Gasperi dem amerikanischen britischen französischen und russischen Botschafter ein italienisches Memorandum über den Südtiroler Grenzstreit mit Österreich überreicht hat in dem die italienischen Gründe für die Zurückbehaltung des Alpengebietes einschließlich des strategisch wichtigen Brennerpasses angeführt werden wird jetzt eine Rede des stellvertretenden Ministerpräsidenten N e n n i bekannt in der dieser die österreichischen Ansprüche auf Südtirol als nicht berechtigt erklärt. Territoriale Ansprüche und alle Grenzfragen sind im Interesse ganz Europas zu lösen.
# 9   Im Zusammenhang mit der vom Hauptquartier der amerikanischen Armee veröffentlichten Mitteilung über die letzte Sitzung des Alliierten Rates wandte sich ein TASS-Korrespon- dent an die Vertreter des Sowjetjsommandos    Wien-Simmering Geiselbergstraße zum Arzt gegangen und nicht mehr zur'ückgekommen. Sie ist bis heute abgängig. Mitteilungen an ihren Vater Raföl Wagner Amstetten bei Firma Julius Berger Lagerplatz _ Hilfe für Südtirol Tausende und aber Tausende von österreichischen Familien haben Verwandte und Bekannte im Ausland. Helfen Sie uns bei unserem Bemühen Südtirol zurückzugewinnen und senden Sie dem Verband der Südtiroler Innsbruck. Maria-Theresien-Straße 36 die Adressen ihrer
# 10  vereinen wir uns zur gemeinsamen Tat! c e. f. Die Times" für ein österreichisches Südtirol In der Konferenz der Außenminister in Paris wurde bekanntlich auch die österreichische Frage und besonders ö Frage Südtirol aufgerollt. Der englische und der amerikanische Außenminister schlagen vor kleine Grenzkorrekturen zugunsten Österreichs vorzunehmen der russische Außenminister beantragte die gesamte Frage zurückzustellen da Österreich nicht auf der Tagesordnung stand.
# 11  Verbotene Platzkonzerte Das Wiener Interalliierte Kommando hat die für Mittwoch den 15. Mai auf dem Ballhausplatz und vor dem Gebäude des Justizpalastes anläßlich_ der Kundgebungen für Südtirol beabsichtigten Platzkonzerte nicht genehmigt. Ebenso mußte auch gestern abend vom Abbrennen von Bergfeürn aufden Anhöhen um Wien abgesehen werden. Britisch-amerikanischer Ernährungsplan
# 12  Unser gesamtes Volk beschwört die große amerikanische Nation die Heimkehr Südtirols in das österreichische Vaterland nach 28 Jahren harter Verfolgung zu ermöglichen. Das Land Andreas Hofers das nach dem ersten Weltkrieg durch einen Irrtum der alliierten Staatsmänner von Österreich losgerissen wurde vertrant auf das demokratische Vermächtnis
# 13  Österreich hoffe ein Land des FriedenswiedieSchweizzu werden. Dr. Grubersöptimismusin wirtschaftlicher Beziehung hat guten Eindruck gemacht. Der österreichische Außenminister hat ehrlich die Schwierigkeiten zugegeben die sich aus der Besetzung ergeben. Er zeigte aber keine Befürcht-ungen und gab bezüglich Südtirols der Überzeugung Ausdruck daß dieses Land niemals italienisch werden würde. Der amerikanische Journalist hob auch hervor. daß Dr. G r u b e r in keiner Weise auf eine Spaltung unter den Alliierten baü oder darauf hoffe.
# 14  Unter diesen Auspizien gingen wir zur Konferenz. Gemäß den Beschlüssen des Ministerrates leitete ich meine Begründung des österreichischen Anspruches damit ein daß sich Österreich Vorbehalte die Südtiroler Frage in ihrer Gesamtheit bei g e- eigneter Gelegenheit aufzurollen. Meine weiteren Ausführungen dienten der Begründung der wirtschaftlichen Notwendigkeit der Rückgliederung der Pustertaler Linie wobei wir uns unter anderem auf ein amerikanisches Gutachten aus dem Jahre 1919 stützen konnten das dem amerikanischen Kompromißvorschlag über Süd'tirol entnommen wurde.
# 15  Italienern zu erhalten wie es 1Ö19 geschah um Fiume den Italienern vorzünthalten. Es erfüllt das österreichische Volk mit Schmerz daß diese große und inächligc Nation ihren Einfluß nicht auch zum Schutz der Südtiroler geltend machen kann die dessen am meisten bedürfen. Die stets hilfsbereite Tatkraft der amerikanischen Offiziere und Soldaten in Österreich ließ uns erwarten daß wir auch in dieser Frage auf Unterstützung hoffen durften. Denn die Auferstehung Österreichs das möge man bedenken ist janichtallcineinePragedermateriellen
# 16  Ich habe in Großbritannien und in Frankreich große Sympathien für unser Land gefunden und ich glaube dlesr Welle der Freundschaft wird noch steigen. Auf die Daür werden wir auch nicht umsonst an die Hilfe der amerikanischen Nation für Südtirol appe'lieren. Ich habe auch die gute Hoffnung daß das russische Volk das so bedeutende Opfer zur Niederringung des Faschismus gebracht hat erkennen wird daß unser österreichisches Volk zu seinen Freunder zählt und wert ist unterstützt zu werden. Gäbe es denn einen besseren Beweis als den Verlauf der Pariser Konferenz daß von einer einseitigen Orientierung Österreichs keine Rede sein
# 17  Dr. Gruber in Paris bevorstehen findet morgen statt Der Außenminister wird mit dem amerikanischen Delegierten dem Wirtschaftsfachmann Thorpe über die Ernährung Österreichs nach Einstellung der Tätigkeit der UNRRA sprechen. Die österreichische Delegation ist augenblicklich mit der Ausarbeitung eines Memorandums über ein Autonomiestatut für Südtirol innerhalb der italienischen Grenzen beschäftigt das wie die österreichischen Delegierten hoffen die Billigung der Großen Vier finden wird. Der Pakt Ober Triest und Istrien
# 18  amerikanische Volk wünscht ein friedliches demokratisches Deutschland das frei und unabhängig wird und bleibt." wird und damit unter die allgemeinen Durchführungsbestimmungen für den Friedensvertrag fällt. Ob das eine ausreichende internationale Garantie für die den Südtirolern zuzustehenden Autonomierechte darstellt wird noch zu untersuchen sein. Dr. Gruber und Botschafter Carandini haben heute Kopien ihres Abkommens dem Generalsekretariat der Konferenz und den Großen Vier" unterbreitet.
# 19  Vor der Pariser Konferenz der stellvertretenden Außenminister wurde die Frage' der kleineren Grenaberichtigungen behandelt. Österreich meldete seinen Anspruch auf das Pustertal (ein Gebiet mit einer Bevölkerung von 65.000 darunter zehn bis zwölf Prozent Italienern) unter Einschluß der Stadt Brixen sowie auf das Kanaltal (362 Quadratkilometer mit 8000 Einwohnern) an. Begründet wurde diese Forderung die mit dem Vorbehalt der Nichtaufgabe der Forderung nach Südtirol durch die österreichischen Regierung vorgebracht wurde vor allem mit den verkehrstechnischen Notwendigkeiten Österreichs wobei der Konferenz Kartenmaterial und ein Auszug aus einem früheren amerikanischen Sachverständigengutachten vorgelegt wurde. Der italienische Vertreter führte dagegen an daß der Alpenhang eine natürliche Grenze bilde er führte ferner Erwägungen in bezug auf die Wasserkräfte an und berief sich auf moralische Momente. Es wurde von der Konferenz eine Unterkommission gebildet die mit dem Studium
# 20  anderen für eine gerechte Regelung der Nationalitätenfrage eintretenden Staaten in Paris gegen die Aufnahme des Südtirolabkommens in den Friedensvertrag mit Italien. Unterdessen ergehen sich englische amerikanische und im anqlo-amerikanischen Bannkreis stehende Staatsmänner und Presseorgane in Lobpreisunqsn des Abkommens Dr. Gruber- de Casperi. Sie loben die Weitsichtigkeit
# 21  Das sind die wahren Hintergründe der eng- Jisch-amerikanischen Billigung des Südtiroier Abkommens Wer sich dem Glauben hingeben würde daß dieses Abkommen den Südtirolem und Österreich hilft der gäbe sich nur schädlichen Illusionen hin.  Keine Verwandlung Österreichs
# 22  es weiter daß ein anderer nicht näher bezeich- neter Gewährsmann der österreichischen Regierung erklärt habe der Anteil der Energie die Italien aus dem Wasserkraftwerken in Südtirol beziehe betrage nicht mehr als 25 Prozent des gesamten italienischen Energieverbrauches. Bundeskanzler Ing. Figl sprach weiters seine große Befriedigung darüber aus daß der stellvertretende amerikanische Außenminister Dean A c h e s o n erklärt habe die Vereinigten Staaten beabsichtigen mit Österreich zur Regelung der Beziehungen einen Vertrag abzuschließen.
# 23  New York HeraJd Tribüne": Viele werden in der freien Sprache in der Mr. B e v i n und sehr russischer Gegenspieler Herr Wischin- Italienische Note über Südtirol London 5. Februar (ACA). Gestern überreichte Ministerpräsident Alcide de Gasperi dem amerikanischen britischen französischen und russischen Botschafter ein italiensch.es Memorandum über den Südtiroler Grenzstreit mit
# 24  die daürnde politische und wirtschaftliche Unausgeglichenheit in der österreichischen Republik zwischen den beiden Weltkriegen war. Die Erklärung verschließt sich nicht dem Standpunkt. daß Italien im Zusammenhang mit den Wasserkraftanlagen die die Italiener in Südtirol zur Versorgung Italiens errichtet haben wirtschaftliche Ansprüche stellen kann Die von Österreich vorgeschlagene Lösung geht dahin daß diese 'Anlagen Italien auch nach der Rückgabe Südtirgls an. öster-^ reich weiterbeliefern sollen und daß ein gemeinsames österreichisch-italienisches Unternehmen gegründet werde das den Aushau der Wasserkraftanlagen zu seiner Aufgabe machen soll.    Parts 2. Mai (AND). Der amerikanische Außenminister Byrnes erklärte auf der Mittwochsitzung der Außenminister die Vereinigten Staaten würden darauf dringen die Besatzungstruppen aus Österreich so bald wie möglich abzuziehen. Bis zur völligen Räumung Österreichs sollten die Truppen der Besatzungsmächte auf je 1 5.0 00 Mann reduziert werden. Der russische Außenminister M o 1 o t o w widersetzte sich der Behandlung dieses Vorschlages mit der Begründung daß Österreich nicht auf der Tagesordnung stehe. Aufgeworfen wurde die ganze Frage dadurch daß Österreichs Ansprüche auf Südtirol zur Sprache kamen. Der Vertreter der Vereinigten Staaten hatte unterstützt durch den britischen Außenminister B e v i n vorgeschlagen daß der Rat der Außenminister kleinere" Berichtigungen der österreichisch-italienischen Grenze erwägen solle. Da Molotow auch dagegen Einspruch erhob wurde die Angelegenheit an den Rat der stellvertretenden Außenminister zu weiterer Prüfung überwiesen. Die Frage der künftigen Kontrolle Italiens
# 25  Im Anschluß an die Debatte über das Problem Südtirol kam es zu einer neürlichen Meinungsverschiedenheit zwischen dem amerikanischen und russischen Außenminister. Byrnes schlug vor daß eine für alle Fragen zuständige alliierte Kommission die Durchführung der Bestimmungen des Friedensvertrages mit Italien überwachen solle.
# 26  Atlantik-Charta dar daß Gebietsveränderun- gen nur in Übereinstimmung mit dem frei zum Ausdruck gebrachten Willen des betreffenden Volkes vorgenommen werden sollen. Es ist dies ein Grundsatz der überall angewandt werden müßte wo er angewandt werden kann. Denn es wäre schwer im jugoslawisch-italienischen Streitfall die moralische Frage aufzuwerfen wenn man gleichzeitig den Österreichern Südtirol einiger Wasserkraftwerke halber vorenthalten oder Millionen aus ihrem Heim vertreiben wollte um jenen Grenzlinien Rechnung zu tragen die aus nackter Machtpolitik gezogen werden sollen. Die neün amerikanischen Vorschläge sind ein Markstein auf dem Wege zur Politik der
# ...
# 46  Bis jetzt sind mindestens schon 88.000 Tonnen amerikanische Waffen und Munition aus der amerikanischen Besatzungszone Deutschlands über die französische Zone österreichs nach Südtirol geliefert worden. Diese Tatsache gewinnt angesichts der am 18. April in Italien bevorstehenden all« meinen Wahlen eine besondere Bödeütürig Außerdem zeugt sie von einem Mißbrauch
# 47  übernahme durch italienische« Militär Um Aufsehen zu vermeiden gehen die amerikanischen Transporte meistens nachts über den Brenner nach Südtirol. Die Ausladung beaufsichtigt von USA-Militär in Zivil wird dann in Südtirol bei den Bahnhöfen Gossen- eaß Sterzing und Franzensfeste vorgenommen. So wurden am 6. April in Sterzing Munitionskisten im Umfang von S0XG0X60 Zentimeter ausgeladen. Von Gossen-
# 48  Weder das amerikanische noch das italienische Dementi sagen auch nur ein St.erbens- iwörtchen darüber was das eigentlich für '"Ausrüstungsgegenstände" sind die in die Italienischen Militärdepots bei Gosßensaß Slerzing und Franzensfeste in Südtirol eingelagert werden. Und seit wann stehen denn Militärlager privaten Firmen zur Verfügung seit wann werden Bestände privater Firmen von Soldaten bewacht? "Geheimen Waffenschmuggel" mag das
# 49  Daß die Forderungen Jugoslawiens für die. amerikanischen und englischen Verhandlungsteilnehmer lediglich ein Vorwand waren ist jedem objektiven Beobachter offensichtlich. Es genügt daran zu erinnern wie die. englischen und amerikanischen Vertreter i946 österreich bei der Geltendmachung'seiner Ansprüche auf den deutschsprachigen Teil Südtirols im Stiche ließen weil um ein Wort Bevins zu gebrauchen Italien die "überfahrt bezahlt werden mußte um zu sehen daß sich die Regierungen der westlichen Großmächte bei der Lösung von Fragen an denen österreich beteiligt ist am allerwenigsten von dessen Interessen leiten lassen. Alle Memoranden der. österreichischen Regierung über die Südtiroler Frage blieben damals unbeachtet. Die Unterbrechung in London hat
# 50  also in Wirklichkeit am wenigsten mit der Kärntner Frage zu tun. Die wahren Beweggründe der amerikanisch- englischen Sprengungstaktik in Lohpon und
# 51  Wiederholt wurden Züge befördert deren Wagen einen dreieckigen gelben Anschlag mit der Aufschrift "Gas" trugen. Ein solcher Zug wurde zum Beispiel am 28. April auf dem Bahnhof in Innsbruck gesehen während zwei andere derartige Müitärtransporte am 4. Mal in Sterzing (Südtirol) standen. Daneben fKegen häufig amerikanische schwere Bomber und Jagdflugzeuge über den österreichischen Luftraum aus Bayern nach
# 52  ¢ Die Jsmnäflbne der Hauptstadt von Schan- tung Tsinan durch die chinesische Volksarmee steht unmittelbar bevor. Nach amerikanischen Agenturmeldungen hat man in offiziellen Kreisen des Kuomintang die Stadt seit Tagen auf-
# 53  eine gemeinsame Wohnunq in der Larochegasse in Hietzing. Sie gab sich als seine Gattin aus und behauptete aus Bozen zu stammen. Polizeilich war sia aber nicht gemeldet. da ihr "Gatte" alliierter Diplomat war. Wie sich nunmehr ergibt ist Dana Superina! jedoch keine gebürtige Südtirolerin sondern eine jugoslawische DP. Nach Angabe von Quartiergeborinnen bei denen das Paar früher gewohnt hat. dürfte sich die Frau als Agentin des amerikanischen Nachrichtendienstes be- tätigt haben. Sie verließ niemals allein das Haus sondern fuhr prinzipiell nur in amerikanischen Autos.
# 54  die "Neü Zürcher Zeitung" wußte zu berichten daß Italien österreich als "Sicherung gegen das Vordringen des Slawentum s" erscheint. Gruber wird heute seine Verhandlungen fortötzen. Sowohl die umfangreiche Verhandlungstätigkeit Grubers wie das bekanntgegehene Verhandlungsprogramm zeigen daß die Südtiroler Frage dabei nur eine ganz nebensächliche Rolle spielt als Vorwand für Verhandlungen üb.er eine engere Bindung österreichs an Italien als Pfeiler des Westblocks unter amerikanischer Führung. Das ist der eigentliche Sinn von Grubers Romreise. Kotikow erläßt Amnestie
# 55  32. Bankenansturm. 33. Biene. 34. Europäische Hauptstadt. 35. Tee englisch. 36. Fragewort. 38"Gattung. 39. Umlaut. 40. Stadt in der Schweiz. 42. Chern. Zeidien für Barium. 43. Weihung. 45 Koranabschnitt. 46. Wütend. 48 Mastspibze. 49. Zu keiner Zeit. 51. Raubvogel pötisch. 53. Bergtrift. 55. Weiblicher Vorname. 56. Inhaltslosigkeit. 57. Stadt in Südtirol. Senkrecht: T. 'Anerkennung. 2. Griechischer Liebesgott. 3. Vorsilbe. 4. Errors excepted abgekürzt. 6. Er französisch. 7. Beeideter Aussteller von Urkunden. 8. Englischer Schriftsteller. 9. Telephon abgekürzt. 11. Schrei französisch. 14. Fischfanggerät. 15. Herbstblume. 18. Schlangenähnlicher Fisch. 19. Vorname eines bekannten amerikanisch. Filmstars ¥ 1930. 20. Wochentag. 23. Allwöchentlicher Ruhetag. 25. Heer.
