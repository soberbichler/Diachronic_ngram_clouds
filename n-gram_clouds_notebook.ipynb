# %% [markdown]
# # Discover a newspaper collection with diachronic Ngram clouds

# %% [markdown]
# Ngrams are connected sequences of n items from a given text or speech sample. This means that words are not considered as individual units, but in relation to each other. For scholars in the humanities, ngrams can be helpful to get an overview of their collection or to identify discourse markers (discourse = a group of related texts belonging to a common system of formation). Ngrams can never be a research result per se - which is true for any output of NLP methods - but they can help to find important patterns in a particular collection.
#
# ![Collection on the topic of Emigration](images/WC_2.PNG)
#
# When ngrams are used to identify discourse markers, it may be useful to create diachronic ngrams to study the change of textual patterns. This notebook therefore shows how diachronic ngrams can be constructed and visualized. For cultural heritage material, visualizations should make it possible to access and experience the collections in new ways. However, they should always be linked to the original documents.
#
# The graphic representation and the original material cannot be perceived as two different elements, they are rather  interwoven and interact with each other. Therefore, this Notebook allows to browse the original texts within the Notebook. Thus the results of the ngram clouds can be researched in the context of the original text.
#
# Acknowledgments:
#
# This work was supported by the European Union's Horizon 2020 research and innovation programme under grant 770299 (NewsEye).

# %% [markdown]
# ## Step by step...
# * [Prepare your collection](#1-bullet)
# * [Install packages in command line](#2-bullet)
# * [Import packages](#3-bullet)
# * [Import your collection](#4-bullet)
# * [Clean and tokenize the text (pre-processing)](#5-bullet)
# * [LLemmatization and pos tagging](#6-bullet)
# * [Have a look at your collection - Create an onegram, bigram or trigram](#7-bullet)
# * [Discover diachronic n-grams for specific years or time periods](#8-bullet)
# * [Browse original texts](#9-bullet)

# %% [markdown]
# ## Prepare your collection <a class="anchor" id="1-bullet"></a>
#
# Your collection should at least contain the original text and information on the date of origin.

# %% [markdown]
# ## Install packages in command line <a class="anchor" id="2-bullet"></a>
#
# If you need help on how to pip install, have a look at this tutorial: https://packaging.python.org/tutorials/installing-packages/
#
# pip install gensim
#
# pip install PyLDAvis
#
# pip install spacy
#
# python -m spacy download de_core_web_sm
#
# pip install pandas
#
# pip install regex
#
# pip install nltk
#
# pip install matplotlib
#
# pip install numpy

# %% [markdown]
# ## Import packages <a class="anchor" id="3-bullet"></a>
#
# Before you can get started, you have to install and import some packages.

# %%
#languange processing imports
import gensim, spacy, logging, warnings
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
import sys
import re, numpy as np, pandas as pd
from pprint import pprint
from nltk.stem.porter import PorterStemmer
from gensim.utils import lemmatize, simple_preprocess

#For the text overview
from nltk import FreqDist

#Word Cloud and Visualization

from wordcloud import WordCloud, STOPWORDS
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import your newspaper collection <a class="anchor" id="2-bullet"></a>
# And have a look at your data

# %%
df = pd.read_csv('y_t_sudtirol.csv', encoding='latin-1')

# %%
len(df)
# Out:
# 4035

# %%
df.groupby(['year','newspaper']).size().unstack().plot(kind='bar',stacked=True)
plt.savefig('bar.png', dpi = 300)

# %% [markdown]
# ## Clean and tokenize the text (pre-processing) <a class="anchor" id="5-bullet"></a>
#
# Before you can start to train the bigram and trigram models, you have to clean the text of your newspaper text blocks. The follwing functions remove punctuations, lower case the text, remove stop words and stem the text.
#
# #### Stop words:
# You can change the language used for the stop words. You can also add your own stop words or other words you would like to ignore. It helps to ignore your search keywords as well as keywords that are overly representative.

# %%
# Functions to clean, tokenize, and stem the data
def initial_clean(text):
    text = re.sub(r'[^\w\s]','',text)
    text = text.lower() 
    text = nltk.word_tokenize(text)
    return text

stop_words = stopwords.words('german')#change the language here
# add your own stop words
stop_words.extend(['italienisch', 'italien', 'italienische', 'italienischen', 'österreich', 'österreichische','österreichischen', 'österreichisch', 'österreichs', 'südtirolerplatz', 'südtriol'])
def remove_stop_words(text):
    return [word for word in text if word not in stop_words]

stemmer = PorterStemmer()
def stem_words(text):
    try:
        text = [stemmer.stem(word) for word in text]
        text = [word for word in text if len(word) > 1] 
    except IndexError: 
        pass
    return text

def apply_all(text):
    return stem_words(remove_stop_words(initial_clean(text)))

# %%
df['tokenized'] = df['text'].apply(apply_all)

# %% [markdown]
# ## Have a look at your collection - Create an onegram, bigram or trigram <a class="anchor" id="7-bullet"></a>

# %%
bigrams_list = list(nltk.bigrams(df['tokenized']))
dictionary = [' '.join([str(tup) for tup in bigrams_list])]
vectorizer = CountVectorizer(ngram_range=(1, 1))
bag_of_words = vectorizer.fit_transform(dictionary)
vectorizer.vocabulary_
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
words_dict = dict(words_freq)
WC_height = 1500
WC_width = 2000
WC_max_words = 200
wordCloud = WordCloud(max_words=WC_max_words, height=WC_height, width=WC_width)
wordCloud.generate_from_frequencies(words_dict)
plt.figure(figsize=(20, 15))
plt.plot
plt.imshow(wordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Lemmatization and pos tagging<a class="anchor" id="6-bullet"></a>
#
#
# We reduce the data to nouns, adjectives, verses and opponents. The package Spacy is used for the pos tagging. Spacy can be used in many differnt languages. To use Spazy in your preferred language, you have to install the right model. This model can be found here: https://spacy.io/usage/models.
#
# We lemmatize the text and remove stop words once more after lemmatization.

# %%
def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts_out = []
    nlp = spacy.load('de_core_news_sm', disable=['parser', 'ner'])
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out
    # remove stopwords once more after lemmatization


data_ready1 = process_words(df['tokenized'])  # processed Text Data!

# %%
bigrams_list = list(nltk.bigrams(data_ready1))
dictionary = [' '.join([str(tup) for tup in bigrams_list])]
vectorizer = CountVectorizer(ngram_range=(3, 3))
bag_of_words = vectorizer.fit_transform(dictionary)
vectorizer.vocabulary_
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
words_dict = dict(words_freq)
WC_height = 1500
WC_width = 2000
WC_max_words = 200
wordCloud = WordCloud(max_words=WC_max_words, height=WC_height, width=WC_width)
wordCloud.generate_from_frequencies(words_dict)
plt.figure(figsize=(20, 15))
plt.plot
plt.imshow(wordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Check the word frequency in munbers:

# %%
bigrams_list = list(nltk.bigrams(data_ready1))
dictionary = [' '.join([str(tup) for tup in bigrams_list])]
vectorizer = CountVectorizer(ngram_range=(1, 1))
bag_of_words = vectorizer.fit_transform(dictionary)
vectorizer.vocabulary_
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
words_dict = dict(words_freq)
print(words_freq[0:10])
# Out:
# [('fragen', 1595), ('regierung', 892), ('abkommen', 735), ('geben', 698), ('außenminist', 651), ('volk', 614), ('erst', 570), ('bevölkerung', 520), ('erklären', 514), ('gruber', 493)]

# %% [markdown]
# ## Discover diachronic n-grams for specific years or time periods <a class="anchor" id="8-bullet"></a>
#
# Here you can create diachronic Ngram clouds for specific years or time frames.

# %%
#Choose specific years or time frames you want to use for the NGram clouds
_1945 = (df['year'] > int('1944')) & (df['year'] <= int('1945'))
_1946 = (df['year'] > int('1945')) & (df['year'] <= int('1946'))
_1947 = (df['year'] > int('1946')) & (df['year'] <= int('1947'))
_1948 = (df['year'] > int('1947')) & (df['year'] <= int('1948'))

#This will be used for the title of the clouds
time_frame = ['1945', '1946', '1947', '1948']

#Here you create a list containing the information on your selected time-frames
selection = []
selection.append(_1945)
selection.append(_1946)
selection.append(_1947)
selection.append(_1948)

#Get your bigrams for every selected time frame
selection[0] = df.loc[_1945]['tokenized']
selection[1] = df.loc[_1946]['tokenized']
selection[2] = df.loc[_1947]['tokenized']
selection[3] = df.loc[_1948]['tokenized']
#Create the diachronic Ngram clouds
i = -1
while i < len(selection) -1:
    i = i +1 
    data_ready3 = process_words(selection[i])  # processed Text Data!
    bigrams_list = list(nltk.bigrams(data_ready3))
    dictionary = [' '.join([str(tup) for tup in bigrams_list])]
    vectorizer = CountVectorizer(ngram_range=(2, 2))
    bag_of_words = vectorizer.fit_transform(dictionary)
    vectorizer.vocabulary_
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    words_dict = dict(words_freq)
    WC_height = 1000
    WC_width = 1500
    WC_max_words = 200
    wordCloud = WordCloud(max_words=WC_max_words, height=WC_height, width=WC_width)
    wordCloud.generate_from_frequencies(words_dict)
    plt.figure(figsize=(15, 8))
    plt.plot
    plt.imshow(wordCloud, interpolation='bilinear')
    plt.title(time_frame[i], size= 'x-large')
    plt.axis("off")
    plt.savefig('cloud.png', dpi = 300)
print()

# %% [markdown]
# ## Browse original texts <a class="anchor" id="9-bullet"></a>
#
# Here you can browse through the original text. To refine the search, you can reduce the search to those texts that contain a specific word. In this example all texts were searched containg the word "amerika*".

# %%
pd.set_option('display.max_colwidth', -1)

lines_ = []
for line in df['text']:
    if 'wirtschaft' in line:
        lines_.append(line)
    
lines_ = pd.DataFrame(lines_, columns =['Original_Text'])
df_select = pd.DataFrame(lines_['Original_Text'])
df_select[50:100]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Original_Text
# 50   der nicht wieder alte Streitfälle au fl eb e n läß t und zu neuen Kriege» führen könnte Die beiden Verfasser des Briefes sind der Ansicht daß Südtirol das österreichische wirtschaftliche Gleichgewicht wieder Herstellen könnte um so mehr als die Erzeugnisse SiidtirolS immer über den Brenner nach Norden ausgeführt wurden und die italienische Wirtschaft dadurch keinen Schaden erleiden würde - -je
# 51   »!c Behindernng feines staatlichen v«kbftbeftinm»n«s»»chtes eingeschränkt fei Auf die Grenzziehung im Kärntner Gebiet eingehend verwies der Redner ns das K a n a l t a l das einen Bestandteil der Südtirolersrage bilde Dieses- Gebiet sei aus ausgesprochen st-rniegischcn Gründen Österreich weg- genommen worden gehöre aber sprachlich geographisch und wirtschaftlich zu uns (Allgemeiner lebhafter Beifall) Der Redner gab der Hoffnung Ausdruck daß diese Grenz- regelung unter Berücksichtigung der gut nachbarlichen Beziehungen durchgeführt werde
# 52   gezeichnete Frage eines ethnischen und wirtschaftlichen
# 53   die Folge hat es unter italienischer Herrschaft zu lassen" Zur wirtschaftlichen Seite der Frage Stellung nehmend erklärt der Bischof: Im Jahre 1919 wurde Nordtirol seines Hinterlandes beraubt und konnte Österreich nicht mehr mit Produkten ans Südtirol versorgen Di« Südtiroler Bauern waren daher gezwungen für ihre Er- zeugniffe italienische Märkte zu suchen Die Italiener haben aber selbst genug Obst und Wein so daß die Märkte überfüllt wckren Als Ergebnis dieser Tat- fache sank der Lebensstandard in Nord und Südtirol iu beträchtlicher Weise und blieb seitdem weit unter dem
# 54   London 18 August (UP) Amtlicherseits wird in Italien bekanntgegeben daß Fachleute des italienischen Außenministeriums sich mit dem Studium der Möglichkeit einer engeren °r>itt» schaftlichen Zusammenarbeit zwischen Öster reich und Italien befassen Eine italienische Kommission die sich derzeit in Wien aufhAt verhandle über das Eisenbahnproblem im Pustertal Dem Präfekten von Bozen wurde Vollmacht erteilt die Verkehrs- und wirtschaftlichen Fragen in Südtirol ln direkten Verhandlungen mit den österreichischen Behörden in Innsbruck zu lösen Handelsdelegation In der Schweiz
# 55   Dr Grober: Was kh von Paris erwarte Wtrfordern nur Gerechtigkeit für Südtirol und wünschen eine BolkS- nbstiminung Ferner müssen di« Be satzungstruppen sobald als möglich unser Land verlasse« und eS imiß auch eine Herstellung der wirtschaftliche« Einheit erfolgen
# 56   Österreich braucht Südtirol Südtirol hat nur wenig Bedeutung für Italien ist jedoch lebenswichtig für Österreich im Interesse der Herstellung von dessen wirtschaftlicher Einheit Die Produkte Südtirols werden von uns mehr gebraucht als von Italien Entscheidend aber ist und bleibt daß es Tiroler sind die immer Österreichcr waren
# 57   die Italien eine vollständige N u tz n t e ß u » g seiner wirtschaftlichen Investitionen sichert Dr Gruber beschäftigte sich dann mit der
# 58   Mit -wirtschaftspolitischen Fragen Es spräche Bundeskanzler Ing Figl Klubobmaun Min a D Raab Staatssekretär Graf Landes partewbmann Dr P l a tz g u m m - r National nn^agnlf'zenz Dr G schnitz er und viel brach/ ?te faBun« »erlief einmütig und er e vor allem in der Frage Südtirols ei: e nbenfi8'8 Treuebekenntnis zu der klaren um eindeutigen Linie der Politik Ing Figls USA und Großbritannien an Warschau»
# 59   im deutschsprachigen Gebiet von Südtirol zu erwirken Sollte eS aus rgend welchen Gründen nicht möglich fein die Friedenskonferenz dazu zu bewegen diesem Hauptvorschlag Österreichs stattzugeben dann  o sieht bas Memorandum vor  sollten folgende Einrichtungen getroffen werden die 1 die politische Freiheit der Südtiroler sichern 2 eine wirtschaftliche Autonomie Herstellen 3 endlich ein Z o l l s o n d e r r e g i m e
# 60   wirtschaftlichen Verhältnisse führen dürfte" Boothby (MP) zum Südtirol-Abhommeti: Eine erntuiigeside LeisStmg In Paris London 7 September (Meuter) Robert
# 61   anzustreücn ist erblickt der Wirtschaftsbund eine Voraus- setzung für die Klarheit und Sicherheit deren die Wirtschaft bedarf Die Lösung der Frage des sogenannten deutschen Eigentums" und die endgültige Inkraftsetzung des National- sozialistengesetzes können zur Schaffung einer Atmosphäre der Beruhigung beitragen Der Wirtschastsbund begrüßt das Abkommen über Südtirol das zwar nicht alle Wünsche befriedigt aber zur Entspannung beiträgt Bei der V e r w a l t u n g d e s freien HafenS Triest muß Österreich ein Platz eingeräumt werden der seiner wirtschaftlichen Bedeutung für Triest entspricht Auch
# 62   Di« österreichische Delegation hat in Paris al» erst« versucht in einer heiklen Streitfrage mit dem Partner zu einer friedlichen Dauerlösung zu gelangen Diese Haltung fernab von einer ungesunden Prestigepolitik aber doch darauf hinziclend de» Südtirolcrn da» größtmögliche Ausmaß an nationalem Eigenleben und wirtschaftlicher Sich« rung zu garantieren hat in den Kreisen der ver schicdenen Delegationen großen Eindruck hervo« gerufen Die Haltung Österreichs ward«
# 63   Die österreichische Delegation verletzte in Paris das neue Kontrollabkommen indem sie der Friedenskonferenz ein Abkommen vorlegt« das vorher nicht vom Alliierten-Rat behandelt wurde Die Sowjetseite ist" der Meinung daß das vorgelegte Abkommen keine Lösung der Kernfragen der deutschsprachigen Bevölkerung Südtirol» ist und ihre langgehegten Erwartungen nicht zum Ausdruck bringt Dieses Abkommen umgehtz di« vollständige Sicherung der nationalen kulturpolitischen und wirtschaftlichen Entwicklung Da» Abkommen läßt die Frage der Grenzen des vorgesehenen autonomen Gebietes offen Die» birgt in sich di« Möglichkeit die geplante Autonomie
# 64   in politischer wie auch in wirtschaftlicher Hinsicht als durchaus befriedigend beurteilt Seit seiuem lebten Besuch habe der Wiederaufbau in Österreich deutliche Fortschritte gemacht was er auch bei einem Besuch in Donawitz habe fcststcllen können Das Abkommen über Südtirol werde von bei englischen Regierung sehr be- grüßt und als ein Beweis für die staatsmiinuische Einsicht der österreichischen Reglerungsvcrtreter angesehen Österreich sei ohne Zweifel guten Wittens aber es seien doch auf dem Wege zur vollen Unabhängigkeit noch manche Schwierigkeiten zu überwinden die vor allem durch Wiedernktiuierung der österreichischen Han-
# 65   staatlich««» der deutschen Industrie und sagtc^ die Denk» scheu würden sich kaum von einer Politik leiten lassen^ die ihnen von Fronlden aufgezwnngen wü-rde Im Verlauf der Debatte bezeichnete Butler daA Abkommen über Südtirol als eines der erfreulichsten Ereignisse der Pariser Konferenz und fragte an bis äst welchem Ausmaß der Ausbau von Handelsve« Ziehungen z w i s ch e n O e st e r r e i ch n n d G r o tzz b r i t a n n i e n möglich sein werde nm Österreich dst« durch jene wirtschaftliche Unterstützung z« gewähren dlii es so sehr benötige
# 66   (APA) Auf Einladung der Tiroler Landesregierung ist Bundesminister Dr H e i n l in Innsbruck eingctroffen um mit den zuständigen Stellen alle schwebenden Wirt- fchaftsfragcu zu erörtern Don den Autzcnhandclsfragen wurden insbesondere das Problem des Wirtschafts- anstausches mit Südtirol und die Wichtigkeit der Schweiz als Wirtschaftspartner Tirols besprochen Hei der Behandlung der Fragen der inneren Bewirtschaftung wiesen die Tiroler Vertreter auf gewiss« Ungleichheiten in der Belieferung und auf die fidr die Tiroler Wirtschaft drückenden Mangelerscheinnngen von Waren hin
# 67   minister Dr <3 KlasterskY Die Südtiroler Parteien an den Rat der Außenminister (APA) Die Vertreter der Südtiroler politischen Parteien haben gestern an den Außen« ministerrat in New Uork nachstehendes Telegramm gerichtet: Die Notwendigkeit bas knk- tnrelle und wirtschaftliche Lebe» in Südtirol zu
# 68   Land wäre verschuldet aber nicht fremdhörig p d österreichische Südtirol-Note an die Alliierten Sicherstellung der wirtschaftlichen Interessen Italiens in Südtirol  Italienische Freihandelszone an der Donau  Südtirol unter dem Schutz der UNO Der österreichische Bundesminister für auswärtige Angelegenheiten Dr Gruber teilte
# 69   dieser Note konkrete Vorschläge für die Ordnung der italienischen wirtschaftlichen Interessen in Südtirol Für die Gebiete die auf Grund der beantragten Volksabstimmung an österreich zurückfallen würden wäre die österreichische Regierung bereit mit Italien die nachfolgenden Abmachungen zu treffen:
# 70   wirtschaftlichen Zusammenarbeit zu machen Die österreichische Regierung weist in den Schlußworten ihrer Note nochmals auf die erstrangige Bedeutung der Lösung der Südtiroler Frage für die Selbständigkeit und Unabhängigkeit des neuen österreich hin Was wir anstreben ist eine endgültige Befriedung an dieser so wichtigen Stelle und die Beseitigung eines Keimherdes von Unruhe der die Vereinten Nationen nur immer wieder beschäftigen müßte Der italienische Versuch durch eine Autonomie in Südtirol
# 71   diese Frage zu lösen wird nach dem Urteil aller Kenner den Frieden in diesem Gebiet nicht wesentlich verbessern weil die tiefgreifenden ethnischen Unterschiede zwischen den Tiroler Bauern und den italienischen Verwaltungsträgem und die Gegenläufigkeit der wirtschaftlichen Interessen die latenten Konfliktstoffe nur zu offen machen würden
# 72   sein daß sie auch vor dem Weltgewissen zu rechtfertigen sind Auch bei dem endgültigen Beschluß über Südtirol wird man fragen: Was ist recht und was ist unrecht? Und auf diese Frage gibt es eine entscheidende Antwort: Südtirol ist ein wesentliches Stück von österreich und es ist ein ganz unwesentlich es Stück von Italien Wir österreicher brauchen diese Landschaft Nicht nur weil sie historisch zu uns gehört nicht nur aus wirtschaftlichen und volkspolitischen Gründen sondern weil unser Staat ohne Südtirol wie schon ein Blick auf die Landkarte zeigt ein ganz groteskes Gebilde bleibt mit einem lächerlich schmalen Grenzstreifen zwischen den großen
# 73   Zum Schluß wandte sich Byrnes der Tagung der Vereinten Nationen in London zu Er bemerkte daß alle Meinungsverschiedenheiten schließlich überwunden worden seien Wiedervereinigung des deutschsprachigen Teiles von Südtirol mit österreich nach einer Volksabstimmung Sie nehme den Standpunkt ein daß in einer Zeit da eine neue Welt aufgebaut wird ein altes Unrecht wieder gutgemacht werden soll Die wirtschaftlichen Interessen Italiens  so zum Beispiel die Frage der italienischen Kraftwerke in Südtirol  könnten voll berücksichtigt werden
# 74   und Südtirol würde auch wirtschaftlich größte Vorteile aus seiner Wiedervereinigung mit österreich gewinnen Was die jugoslawischen Ansprüche auf Teile von Kärnten betrifft so nehme die österreichische Regierung
# 75   Parlament Innsbruck 4 März Das Tagblatt der Südtiroler die Dolomiten" zieht aus der Rede Bevins wie auch aus anderen englischen Stimmen den Schluß daß die englische Regierung den Willen hat bei der Grenzziehung die volksmäßigen Faktoren den wirtschaftlichen vorzuziehen Denn so heißt es in Kommentaren zur Rede es wäre ja nicht ersichtlich warum man über wirtschaftliche Fragen nicht durch Bildung von zwischenstaatlichen Gesellschaften
# 76   verlautet halten die stellvertretenden Außenminister gegenwärtig Besprechungen über die italienisch-österreichische Grenze ab Der österreichische Vertreter in London Dr S c hm i d t erklärte daß österreich das Gebiet von Bozen als Teil Südtirols aus ethnographischen und wirtschaftlichen Gründen zurückverlange Gegenwärtig lebten in österreich 8 00 00 Südtiroler die in ihre Heimat zurück wollen_ Die kanadische Spionageaffäre
# 77   teilt Professor Nicolussi mit daß von den 80000 aus- gesiedelren Südtirolern derzeit etwa 6000 in der Steiermark leben Die wirtschaftliche Lage der Ausgesiedelten sei im allgemeinen ungünstig so daß der weitaus größte Teil durch Hilfsmaßnahmen (Schweizer Spende) und durch die UNRRA unterstützt werden müssen Ãberprüfung der Sudetendeutschen in der
# 78   regelnden gesetzlichen Anordnungen Von ganz wesentlichem Wert für die praktische Benutzbarkeit ries Werkes das heuer nach siebenjähriger Pause im 41 Jahrgang erscheint ist diÂ« Ãbersicht über die Organisation der obersten Bundes- und Landesbehörden und der wirtschaftlichen Zentralstellen die gleichfalls aiuf dÂ«n neuesten Stand gebracht wurde _ Die Südtiroler Frage behandelt Ing Bruno Fraeeschini in einem Vortrag der Samstag 27 April 1830 Uhr in der Urania stattfindet Der Vorstand des österreichischen Gewerkschaftsbundes hat sich in
# 79   Die Journalisten interessieren sich besonders für nachstehende Probleme: Verschleppte Personen Ernährung und Landwirtschaft Entnazifizierung Handel und Gewerbe Gesundheitswesen Politik einschließlich Zivilverwaltung Nachrichtenzensur und Finanzwesen Südtiroler Journalist nach österreich ausgewiesen Bozen 19 April (AND) Am 9 April wurde der Südtiroler Journalist Dr Anton Heiß der als Leitartikler bei der
# 80   Europas meint der kann einer solchen Sprache nichts gegenüberstellen am allerwenigsten aber strategische Notwendigkeiten der Brennergrenze Die wirtschaftliche Bedeutung Südtirols ich will nicht leugnen daß die Wiedcrheimkehr Südtirols in sein österreichisches Heimatland sowohl für Südtirol selbst wie auch für österreich nicht nur ein politisches Problem sondern auch eine wirtschaftliche Frage ist Als Obst- und Weinland ist Südtirol für Italien ohne Bedeutung Unsere Südtiroler Bauern haben unter der italienischen Herrschaft angesichts der Konkurrenz der anderen Provinzen
# 81   schwerste Not gelitten österreich hat gerade mit dem Verlust Südtirols seine wertvollste un'd wirtschaftlich stärkste Provinz verloren
# 82   zu den verschleppten Personen" gehören in der Bäckerei beschäftigt waren in der die Brotlaibe an die Gefangenen ausgegeben wurden Alle vier sind seither verschwunden Uber ihre Nationalität ist nichts bekannt den italienischen Staat oder durch italienische Körperschaften in Südtirol errichteten Kraftwerke Die österreichische Regierung hat nicht die Absicht bestehende rechtsgültige Besitzverhältnisse zu ändern Der bisherige Stromexport aus Südtiro! nach Italien muß aufrecht erhalten werden Der italienischen Mind er heit im österreichischen Südtirol wird in kulturellen wirtschaftlichen und nationalen Wünschen vollkommene demokratische Freiheit garantiert sein
# 83   Störungen der österreichischen Republik zwischen den zwei Weltkriegen kam Die Erklärung gesteht zu daß Italien wirtschaftliche Ansprüche im Zusammenhang mit den von Italien erbauten und von Italien ausgenützten Wasserkraftwerken hat Die von den österreichern vorgeschlagene Lösung geht dahin daß die Wasserkraftwerke weiterhin von Italien benützt werden sollen wenn Südtirol zu österreich zurückkehrt und daß eine gemeinsame österreichisch-italienische Gesellschaft für die zukünftige Entwicklung der Wasserkräfte verantwortlich sein soll In Konferenzkreisen wird daran erinnert daß der britische Außenminister Bevin
# 84   Gedanken an Ausnützung der Zwangslage eines anderen zurück Im Geiste der Versöhnlichkeit hat sich österreich auch das Interesse Italiens vor Augen gehalten das in seiner zwanzigjährigen Herrschaft im Gebiete von Südtirol eine Reihe von wirtschaftlichen Investitionen getätigt hat Das daraus entstandene wirtschaftliche Interesse ItaJiens an diesem Gebiet wird von österreich anerkannt und die österreichische Regierung hat deshalb die nachfolgenden Vorschläge an die alliierten Mächte gerichtet:
# 85   Italien befürchtet anscheinend der Verlust der Brennergrenze würde seine strategische Stellung erschweren: dieses Argument erscheint unter den gegenwärtigen Verhältnissen wohl nicht mehr durchschlagend Die österreichische Regierung hat sich aber trotzdem bereit erklärt das Gebiet von Südtirol mit dem Brennerpaß unter die Kontrolle der Vereinten Nationen zu stellen Sie hat darüber hinaus ihren Willen bekräftigt nach Lösung der Südtiroler Frage zu Italien in die bestmögliche wirtschaftliche Zusammenarbeit einzutreten
# 86   Salzburg 4 Mai (AND) Die Kammer für Landwirtschaft und Ernährung in Salzburg erließ an alle Bauern Bäuerinnen und landwirtschaftlichen Arbeiter einen Aufruf am Sonntag geschlossen an der großen überparteilichen Kundgebung für die Rückgabe Südtirols bei der Vertreter aller Parteien sprechen werden teilzunehmen Wir wollen damit zum Ausdruck bringen daß sich die Bauern Salzburgs eins fühlen mit den Bauern Südtirols daß Südtirol und seine Bauern ein Teil österreichs sind und die Abtrennung dieses Landes ein Unrecht war das heute gutgemacht werden muß denn nur Gerechtigkeit ist Fried e Schlechte Ernteaussichten in Ungarn
# 87   Schließen wir über Parteigrenzen und Weltanschauungen hinaus einen Bund demokratischer österreichischer Einigkeit Treten wir in den großen Fragen unserer Heimat geeinigt vor die Alliierten Erbringen wir durch eine solche demokratische Waffenbrüderschaft den Beweis daß die Welt uns vertrauen kann und daß wir imstande sind die Herren unseres Schicksals zu sein Durch eine solche Politik können wir nicht nur Südtirol gewinnen sondern auch die volle wirtschaftliche und politische Souveränität österreichs Gemeinsam und geeinigt wollen wir den Großmächten zurufen: Macht wieder gut was einst schlecht gemacht wurde! Reißt nicht ein lebendes Stück aus unserem österreichischen Volkskörperl Gebt uns das österreichische S ü d t i r o 1!
# 88   für die Vereinigung dieses kleinen vielgeprüften Volkes mit seinen Landsleuten nördlich des Brenners ist Wir begrüßen diese Stellungnahme der Times und hoffen auf einen günstigen Widerhall Wie bekannt hat die österreichische Regierung in der Frage der Elektrizitätswerke und Wasserkräfte in Südtirol der italienischen Regierung weitestgehende Zugeständnisse ange- boten: österreich will aus den wirtschaftlichen Investitionen Italiens in Südtirol keinen Gewinn schlagen Wir suchen in Südtirol nicht wirtschaftliche Bereicherung sondern Erfüllung eines nationalen Herzenswunsches _ Der Bundeskanzler für rücksichtslose
# 89   Tälern der Etsch und der Ei sack wollen die Menschen zurück ins österreichertum wollen lieber unseren Hunger teilen als unter Fremdherrschaft weiterleben Was die britischen Delegierten aus diesem Kampf um Südtirol ersehen können ist ein Aufschäumen edelster Menschheitsgesinnungen selbstlosester Treue leidenschaftlichsten Freiheitsdranges Und sie werden sicher selbst die Empfindung haben daß man einer solchen aus tiefstem Herzen kommenden Volksbewegung nicht die kühlen Diplomatenworte entgegenstellen darf es gehe nicht um eine rein ethnische Frage es müßten auch die wirtschaftlichen Faktoren in Betracht gezogen
# 90   Die These' von den wirtschaftlichen Faktoren" wurde vom britischen Außenminister im
# 91   sich vor allem um die Rückgabe des Pustertales südöstlich des Brennerpasses Die günstige Erledigung dieser Frage würde die Eisenbahnverbindungen zwischen dem östlichen und dem westlichen Teil Tirols erleichtern Die Frage Südtirols soll jetzt nicht eröTtert werden Dr Gruber weist jedoch darauf hin daß diese Frage für österreich wirtschaftlich von vitaler Bedeutung ist Er habe die Absicht den französischen
# 92   gestern im Unterhaus gefragt welche wirtschaftlichen Gründe für den Verbleib Südtirols bei Italien bestehen abgesehen von den kürzlich erwähnten Wasserkraftwerken Bevin antwortete darauf: Es gibt in Südtirol außer den erwähnten Wasserkraftwerken einige Aluminiumwerke und chemische Fabriken sowie eine wichtige Fabrik die künstlichen Stickstoff für Düngemittel erzeugt Weiterhin kommen nach den Berichten
# 93   daß wir die politische Freiheit und die wirtschaftliche Entwicklungsfähigkeit wiedergewinnen auf der anderen Seite eine etwas beängstigende Zurückhaltung der Regierungskreise hinsichtlich Südtirols  das ist in kürzester Fassung der Succus der Debatte Aber für uns österreicher bleibt doch ein verwirrendes Gefühl zurück wenn wir den Gegensatz zwischen der guten Absicht und der mangelnden Wirkung zwischen den schönen Reden und der minder schönen Realität ins Auge fassen
# 94   österreich hoffe ein Land des FriedenswiedieSchweizzu werden Dr Grubersöptimismusin wirtschaftlicher Beziehung hat guten Eindruck gemacht Der österreichische Außenminister hat ehrlich die Schwierigkeiten zugegeben die sich aus der Besetzung ergeben Er zeigte aber keine Befürcht-ungen und gab bezüglich Südtirols der Ãberzeugung Ausdruck daß dieses Land niemals italienisch werden würde Der amerikanische Journalist hob auch hervor daß Dr G r u b e r in keiner Weise auf eine Spaltung unter den Alliierten baue oder darauf hoffe
# 95   starken Kern von aufrichtigen Demokraten gäbe um ruhig die Gefahr auf sich nehmen zu können die österreicher allein das Werk fortsetzen zu lassen das die Alliierten begonnen haben General Bethouart meinte weiters über Südtirol: Wenn die Viererkonferenz die Forderung nach Grenzberichtigung neuerlich ab- weisen sollte wäre das Vertrauen das die österreicher in die Grundsätze der Demokratie haben stark erschüttert Nach der Erklärung daß die Kernfrage von der die politische und wirtschaftliche
# 96   seines wirtschaftlichen Systems sondern auch
# 97   Unter diesen Auspizien gingen wir zur Konferenz Gemäß den Beschlüssen des Ministerrates leitete ich meine Begründung des österreichischen Anspruches damit ein daß sich österreich Vorbehalte die Südtiroler Frage in ihrer Gesamtheit bei g e- eigneter Gelegenheit aufzurollen Meine weiteren Ausführungen dienten der Begründung der wirtschaftlichen Notwendigkeit der Rückgliederung der Pustertaler Linie wobei wir uns unter anderem auf ein amerikanisches Gutachten aus dem Jahre 1919 stützen konnten das dem amerikanischen Kompromißvorschlag über Süd'tirol entnommen wurde
# 98   Die Gerechtigkeit ist unteilbar in konsequenter Verfolgung dieses Prinzips hat österreich eine Stellungnahme zur Frage Triest abgelehnt und auf das Selbstbestimmungsrecht der Bevölkerung verwiesen Italien kämpft um Triest das vom italienischen Staat getrennt werden soll wobei jedoch die Erhaltung des italienischen Volkstums durch die Intematio- nalisierung sichergestellt ist Für die österreichische Bevölkerung Südtirols wäre eine solche Lösung in den Jahren seit 1919 als Befreiung empfunden worden denn nicht nur die Abtrennung vom Mutterland die Zerreißung der natürlichen und wirtschaftlichen Zusammenhänge sondern vor allem die Vernichtung des Volkstums war die Folge der Annexion Südtirols durch Italien Vielleicht beginnen jetzt nach der Vorentscheidung über die italienische Ostgrenze einige Italiener zu verstehen warum sich die Südtiroler so verzweifelt gegen
# 99   Man kann sagen daß die Friedensmacher von 1946 mit den Problemen die sie zu behandeln haben sachlich weitaus besser vertraut sind als ihre Vorgänger von 1919 Nicht ein einziger ist sich darüber im unklaren daß Südtirol urösterreichisches Land ist weitaus überwiegend von österreichern bewohnt und daß 1919 ein schweres Unrecht an Südtirol begangen worden ist Aber man ist bei den Irrtümern von 1919 nicht stehengeblieben Man hat jetzt wirtschaftliche" Gründe für das Verbleiben Südtirols bei Italien entdeckt
